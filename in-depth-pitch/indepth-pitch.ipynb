# %%
## import libraries
import pandas as pd

# %%
## import CLT data
df = pd.read_excel("raw-data/clt-database.xlsx")
df
# Out:
#                                               Name           Zip  \
# 0                                   Northfield LDC         10302
# 1                                ReAL Edgemere CLT  11691\n11692
# 2                                  Brownsville CLT         11212
# 3                                Brooklyn Level Up         11210
# 4                                    Chinatown CLT         10038
# 5                                    Interboro CLT            --
# 6                                Cooper Square CLT  10003\n10009
# 7                                         RAIN CLT         10009
# 8                            This land is ours CLT         10003
# 9                        East Harlem El Barrio CLT         10035
# 10                          We stay / Nos Quedamos         10451
# 11                            Mary Mitchell Center         10460
# 12                          Northern Manhattan CLT  10033\n10040
# ...

# %%
## check datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   18 non-null     object
#  1   Zip                    18 non-null     object
#  2   HQ or Project Address  16 non-null     object
#  3   Neigborhood            18 non-null     object
#  4   Borough                18 non-null     object
#  5   Website                18 non-null     object
#  6   Year Est               18 non-null     int64
#  7   Has land               18 non-null     object
#  8   Has buildings          18 non-null     object
#  9   Status                 18 non-null     object
#  10  Redline rating         18 non-null     object
#  11  Focus                  18 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 1.8+ KB

# %%
## convert year into int
df['Year Est'].astype(int)
# Out:
# 0     2022
# 1     2021
# 2     2018
# 3     2020
# 4     2021
# 5     2018
# 6     1994
# 7     1980
# 8     2020
# 9     2014
# 10    2017
# 11    2018
# 12    2018
# 13    2018
# 14    2014
# 15    2019
# 16    2018
# 17    2020
# Name: Year Est, dtype: int64

# %%
## see when most of the CLTs were founded
df.value_counts("Year Est")
# Out:
# Year Est
# 2018    6
# 2020    3
# 2014    2
# 2021    2
# 1980    1
# 1994    1
# 2017    1
# 2019    1
# 2022    1
# Name: count, dtype: int64

# %%
## see how many CLTs were est since 2020
df.query("2020 <= `Year Est`").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 17
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   6 non-null      object
#  1   Zip                    6 non-null      object
#  2   HQ or Project Address  5 non-null      object
#  3   Neigborhood            6 non-null      object
#  4   Borough                6 non-null      object
#  5   Website                6 non-null      object
#  6   Year Est               6 non-null      int64
#  7   Has land               6 non-null      object
#  8   Has buildings          6 non-null      object
#  9   Status                 6 non-null      object
#  10  Redline rating         6 non-null      object
#  11  Focus                  6 non-null      object
# dtypes: int64(1), object(11)
# memory usage: 624.0+ bytes

# %%
## see where most CLTs are
df.value_counts("Borough")
# Out:
# Borough
# Manhattan        6
# Bronx            4
# Brooklyn         3
# Queens           3
# City-wide        1
# Staten Island    1
# Name: count, dtype: int64

# %%
## see what the redline data is for most CLTs
df.value_counts("Redline rating")
# Out:
# Redline rating
# D      11
# B       3
# C       2
# --      1
# A/B     1
# Name: count, dtype: int64

# %%
## see where the B rated CLTs are
df.query('`Redline rating` == "B"')
# Out:
#                                               Name    Zip  \
# 3                                Brooklyn Level Up  11210
# 13  Northwest Bronx Community and Clergy Coalition  10468
# 16                                      Chhaya CDC  11372
#
#                       HQ or Project Address     Neigborhood   Borough  \
# 3   3302 FARRAGUT RD Brooklyn NY 11210-2737        Flatbush  Brooklyn
# 13          103 E 196th St. Bronx, NY 10468  Norhwest Bronx     Bronx
# 16   37-43 77th St #2, Jackson Heights, NY   Jackson Height    Queens
#
#                                     Website  Year Est Has land Has buildings  \
# 3                      https://bklvlup.org/      2020       No            No
# 13  https://www.northwestbronx.org/bronxclt      2018       No            No
# 16                                       --      2018       No            No
#
#     Status Redline rating                                              Focus
# ...

# %%
## exmaine the CLTs with land
df.query('`Has land` == "Yes"')
# Out:
#                 Name           Zip  \
# 1  ReAL Edgemere CLT  11691\n11692
# 5      Interboro CLT            --
# 6  Cooper Square CLT  10003\n10009
# 7           RAIN CLT         10009
#
#                              HQ or Project Address  \
# 1                                              NaN
# 5                                               --
# 6                                               --
# 7  336 East 4th Street 2B New York, New York 10009
#
#                                       Neigborhood    Borough  \
# 1                                        Edgemere     Queens
# 5  City-wide: east BK, South BX, Southeast Queens  City-wide
# 6                                 Lower East Side  Manhattan
# 7                                 Lower East Side  Manhattan
#
#                                     Website  Year Est Has land Has buildings  \
# 1          https://www.realedgemereclt.org/      2021      Yes            No
# ...

# %%
## exmaine the CLTs with buildings
df.query('`Has buildings` == "Yes"')
# Out:
#                                               Name           Zip  \
# 2                                  Brownsville CLT         11212
# 6                                Cooper Square CLT  10003\n10009
# 9                        East Harlem El Barrio CLT         10035
# 10                          We stay / Nos Quedamos         10451
# 14  Mott Haven-Port Morris Community Land Stewards         10454
# 17                               East New York CLT         11208
#
#                                 HQ or Project Address      Neigborhood  \
# 2   519 Rockaway Avenue, 4th floor Brooklyn, NY 11...      Brownsville
# 6                                                  --  Lower East Side
# 9            104 East 126th Street New York, NY 10035      East Harlem
# 10                      425 E 161 St, Bronx, NY 10451  Melrose Commons
# 14            Willis Ave between East 139th and 141st      South Bronx
# 17              2966 Fulton Street Brooklyn, NY 11208    East New York
#
# ...

# %%
## exmaine the CLTs with neither land nor buildings
df.query('(`Has buildings` == "No") and `Has land` == "No"')
# Out:
#                                               Name           Zip  \
# 0                                   Northfield LDC         10302
# 3                                Brooklyn Level Up         11210
# 4                                    Chinatown CLT         10038
# 8                            This land is ours CLT         10003
# 11                            Mary Mitchell Center         10460
# 12                          Northern Manhattan CLT  10033\n10040
# 13  Northwest Bronx Community and Clergy Coalition         10468
# 15                              Western Queens CLT         11001
# 16                                      Chhaya CDC         11372
#
#                                HQ or Project Address  \
# 0        160 Heberton Avenue Staten Island, NY 10302
# 3            3302 FARRAGUT RD Brooklyn NY 11210-2737
# 4                   217 Park Row, New York, NY 10038
# 8   16 2nd Ave New York City, NY 10003 United States
# ...

# %%
## expand columns to see full values of "focus" column
pd.set_option('display.max_colwidth', None)

# %%
## examine focus of each CLT, and how they compare to year est and borough
df[["Borough", "Focus", "Year Est"]].sort_values(by = "Year Est", ascending = False)
# Out:
#           Borough  \
# 0   Staten Island
# 4       Manhattan
# 1          Queens
# 8       Manhattan
# 17       Brooklyn
# 3        Brooklyn
# 15         Queens
# 5       City-wide
# 2        Brooklyn
# 11          Bronx
# 12      Manhattan
# 13          Bronx
# 16         Queens
# 10          Bronx
# 14          Bronx
# 9       Manhattan
# 6       Manhattan
# 7       Manhattan
#
#                                                                                                           Focus  \
# 0                                                  Housing, weatherization,  economic and community development
# 4                                                                               Housing, small business support
# 1                                                           Housing, climate resilience, communmity development
# 8                                                          Housing, green spaces, community, commercial support
# ...
