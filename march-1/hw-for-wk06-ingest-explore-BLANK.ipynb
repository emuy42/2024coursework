# %% [markdown]
# # Homework for Week 3
#
# The goal for this homework is to see the relevant journalistic uses for what we learned in class in week 2.
#
# 1. access specific data within a dataset,
# 2. break down larger datasets into smaller chunks (subset),
# 3. Ingest different types of spreadsheets into Pandas,
# 4. Gather general info about our dataframes

# %% [markdown]
# # List Slicing
# ## Natural disasters list
#
# The Small Business Administration has a list of natural disasters that cause extensive economic damage. Run the next cell to pull the list into memory

# %%
disasters = [
        "Landslides",
        "Earthquake",
        "Wildfires",
        "Tornadoes",
        "Hurricane",
        "Wind Storm",
        "Winter Freeze",
        "Ice Storm",
        "Drought",
        "Tsunami",
        "Flash floods",
        "Mudslides",
        "Torrential rainfall",
        "Riverine floods",
        "Tidal Surge"
         ]

# %%
## call the disaster list here
print(disasters)
# Out:
# ['Landslides', 'Earthquake', 'Wildfires', 'Tornadoes', 'Hurricane', 'Wind Storm', 'Winter Freeze', 'Ice Storm', 'Drought', 'Tsunami', 'Flash floods', 'Mudslides', 'Torrential rainfall', 'Riverine floods', 'Tidal Surge']

# %%
## the first item in the list
disasters[0]
# Out:
# 'Landslides'

# %%
## call the penultimate item (without manually counting the number of items) -- i.e. second to last
disasters[-2]
# Out:
# 'Riverine floods'

# %% [markdown]
# ### Clarification:
#
# For the next two questions, I am referring to numerical positions rather than zero-indexed positions. In other words, you will have to translate the numerical position into zero-indexed positions in your slicing.

# %%
## create a new list called disasters_subset that holds the 3rd to 6th items inclusive
disasters_subset = disasters[2:6]
disasters_subset
# Out:
# ['Wildfires', 'Tornadoes', 'Hurricane', 'Wind Storm']

# %%
## create a new list called disasters_subset2 that holds the 2nd through 8th items -- assuming inclusive below
disasters_subset2 = disasters[1:8]
disasters_subset2
# Out:
# ['Earthquake',
#  'Wildfires',
#  'Tornadoes',
#  'Hurricane',
#  'Wind Storm',
#  'Winter Freeze',
#  'Ice Storm']

# %% [markdown]
# ## Pandas - Importing data
#
# Please download from Google Drive the following data and then upload it into this notebook:
#
# - <a href="https://drive.google.com/file/d/1izg0nXFm8vBJAhz77LFdSMQGP4STvpEk/view?usp=sharing">EMS excerpt</a>,
#
# - <a href="https://docs.google.com/spreadsheets/d/1sUEttreon8IKzCmsfRQ6cPA1lfeuNDu9/edit?usp=sharing&ouid=107646296031550187966&rtpof=true&sd=true">Customs, Border Patrol</a>
#
# **Give yourself time to download it. Some of the files are large!**

# %%
## import the pandas library in this cell
import pandas as pd

# %% [markdown]
# ### Ingest the following dataset into this note:
#
# - ```ems20_1st_6months_excerpt.csv``` into a dataframe named ```ems2020_excerpt_df```

# %%
## import data and store in dataframe
ems2020_excerpt_df = pd.read_csv("raw_data/ems20_1st_6months_excerpt.csv")

# %%
## call the first 10 rows
ems2020_excerpt_df.head(10)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        201101264  2020-04-19 10:25:47            INJMIN
# 1        200423766  2020-02-11 19:25:47              CARD
# 2        200434110  2020-02-12 21:36:52               UNC
# 3        201610121  2020-06-09 00:52:30              DRUG
# 4        200034112  2020-01-03 20:44:05              DRUG
# 5        200530247  2020-02-22 01:26:18              DRUG
# 6        200543279  2020-02-23 19:08:27               UNC
# 7        201471743  2020-05-26 12:45:46            INJURY
# 8        201180116  2020-04-27 00:57:48               EDP
# 9        200572739  2020-02-26 15:15:25            CARDBR
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            7          INJMIN                          7
# 1                            3            SICK                          6
# 2                            2             UNC                          2
# 3                            4            DRUG                          4
# 4                            4            DRUG                          4
# 5                            4            DRUG                          4
# 6                            2             UNC                          2
# 7                            5          INJURY                          5
# 8                            7            EDPC                          7
# 9                            2          CARDBR                          2
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    04/19/2020 10:26:24 AM                              Y
# 1    02/11/2020 07:25:56 PM                              Y
# 2    02/12/2020 09:37:24 PM                              Y
# 3    06/09/2020 12:52:44 AM                              Y
# 4    01/03/2020 08:44:11 PM                              Y
# 5    02/22/2020 01:27:21 AM                              Y
# 6    02/23/2020 07:08:44 PM                              Y
# 7    05/26/2020 12:46:04 PM                              Y
# 8    04/27/2020 12:58:07 AM                              Y
# 9    02/26/2020 03:16:35 PM                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                            37    04/19/2020 10:26:24 AM  ...           40.0
# 1                             9    02/11/2020 07:26:09 PM  ...           52.0
# 2                            32    02/12/2020 09:38:27 PM  ...          106.0
# 3                            14    06/09/2020 12:52:59 AM  ...           19.0
# 4                             6    01/03/2020 08:44:17 PM  ...           66.0
# 5                            63    02/22/2020 01:27:41 AM  ...           25.0
# 6                            17    02/23/2020 07:09:16 PM  ...           44.0
# 7                            18    05/26/2020 12:46:15 PM  ...           41.0
# 8                            19    04/27/2020 12:58:15 AM  ...           50.0
# 9                            70    02/26/2020 03:16:49 PM  ...          106.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                 8.0              201.0                      7.0
# 1                14.0              207.0                     10.0
# 2                32.0              410.0                     27.0
# 3                 4.0              108.0                      2.0
# 4                39.0              312.0                     15.0
# 5                 8.0              111.0                      4.0
# 6                 8.0              204.0                      9.0
# 7                17.0              202.0                      8.0
# 8                11.0              208.0                     10.0
# 9                28.0              410.0                     27.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                  15.0                N                       N
# 1                  15.0                N                       N
# 2                   8.0                N                       N
# 3                  12.0                N                       N
# 4                   7.0                N                       N
# 5                  12.0                N                       N
# 6                  15.0                N                       N
# 7                  15.0                N                       N
# 8                  16.0                N                       N
# 9                   5.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 0                 N                   N  chunk170.csv
# 1                 N                   N  chunk166.csv
# 2                 N                   N  chunk166.csv
# 3                 N                   N  chunk171.csv
# 4                 N                   N  chunk165.csv
# 5                 N                   N  chunk167.csv
# 6                 N                   N  chunk167.csv
# 7                 N                   N  chunk171.csv
# 8                 N                   N  chunk170.csv
# 9                 N                   N  chunk167.csv
#
# [10 rows x 32 columns]

# %%
## call the last 5 rows
ems2020_excerpt_df.tail(5)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 13112                            2          DIFFBR                          2
# 13113                            5          INJURY                          5
# 13114                            6            SICK                          6
# 13115                            4          MVAINJ                          4
# 13116                            2          DIFFFC                          2
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 13112    02/08/2020 07:52:34 PM                              Y
# 13113    01/03/2020 10:51:39 PM                              Y
# 13114    02/11/2020 09:52:09 PM                              Y
# 13115    06/22/2020 03:58:07 PM                              Y
# 13116    03/26/2020 07:33:50 PM                              Y
#
#        DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  \
# 13112                           181    02/08/2020 07:53:00 PM  ...
# 13113                             6    01/03/2020 10:52:21 PM  ...
# 13114                            60    02/11/2020 09:52:18 PM  ...
# 13115                            23    06/22/2020 03:58:19 PM  ...
# 13116                            31    03/26/2020 07:34:08 PM  ...
#
#       POLICEPRECINCT CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 13112           72.0                38.0              307.0
# 13113           75.0                42.0              305.0
# 13114           48.0                15.0              206.0
# 13115           62.0                47.0              311.0
# 13116          103.0                27.0              412.0
#
#        COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 13112                     15.0                   7.0                N
# 13113                     19.0                   8.0                N
# 13114                     10.0                  15.0                N
# 13115                     21.0                  11.0                N
# 13116                     29.0                   5.0                N
#
#       SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  TRANSFER_INDICATOR  \
# 13112                       N                 N                   N
# 13113                       N                 N                   N
# 13114                       N                 N                   N
# 13115                       N                 N                   N
# 13116                       N                 N                   N
#
#              source
# 13112  chunk166.csv
# 13113  chunk165.csv
# 13114  chunk166.csv
# 13115  chunk172.csv
# 13116  chunk168.csv
#
# [5 rows x 32 columns]

# %%
## call a 20 random rows
ems2020_excerpt_df.sample(20)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 12468        200124027  2020-01-12 21:38:31             ABDPN
# 1900         200682098  2020-03-08 14:17:41               EDP
# 761          200462137  2020-02-15 13:50:33            CARDBR
# 8050         201120514  2020-04-21 03:36:29             HYPTN
# 9616         200272892  2020-01-27 15:16:41              SICK
# 4279         200572189  2020-02-26 13:06:40            INJURY
# 8452         201142721  2020-04-23 18:14:11            CDBRFC
# 9264         200890753  2020-03-29 03:43:26               EDP
# 3019         201300338  2020-05-09 02:36:19            DIFFFC
# 10428        200230544  2020-01-23 04:51:04             OTHER
# 11961        200851264  2020-03-25 07:24:44            RESPIR
# 11963        200804014  2020-03-20 18:20:23               EDP
# 1017         201233712  2020-05-02 22:14:11            UNKNOW
# 1528         200143685  2020-01-14 18:45:20            RESPIR
# 630          201310723  2020-05-10 06:03:55               EDP
# 9143         200744362  2020-03-14 21:48:39            UNKNOW
# 5729         200062529  2020-01-06 14:11:09            SICMIN
# 5427         201504064  2020-05-29 23:39:31            SICMIN
# 9            200572739  2020-02-26 15:15:25            CARDBR
# 1099         200300553  2020-01-30 04:53:34            MVAINJ
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 12468                            5          DIFFBR                          2
# 1900                             7             EDP                          7
# 761                              2          CARDBR                          2
# 8050                             7           HYPTN                          7
# 9616                             6            SICK                          6
# 4279                             5          INJURY                          5
# 8452                             2          CDBRFC                          2
# 9264                             7             EDP                          7
# 3019                             2            SICK                          6
# 10428                            6           OTHER                          6
# 11961                            4          RESPIR                          4
# 11963                            7             EDP                          7
# 1017                             4          UNKNOW                          4
# 1528                             4          DIFFBR                          2
# 630                              7             EDP                          7
# 9143                             4          UNKNOW                          4
# 5729                             7          INBLED                          3
# 5427                             7          SICMIN                          7
# 9                                2          CARDBR                          2
# 1099                             4          INJMAJ                          3
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 12468    01/12/2020 09:39:45 PM                              Y
# 1900     03/08/2020 02:17:56 PM                              Y
# 761      02/15/2020 01:52:06 PM                              Y
# 8050     04/21/2020 03:37:26 AM                              Y
# 9616     01/27/2020 03:32:18 PM                              Y
# 4279     02/26/2020 01:06:52 PM                              Y
# 8452     04/23/2020 06:14:22 PM                              Y
# 9264                        NaN                              N
# 3019     05/09/2020 02:36:48 AM                              Y
# 10428    01/23/2020 04:51:36 AM                              Y
# 11961    03/25/2020 07:25:19 AM                              Y
# 11963    03/20/2020 06:22:51 PM                              Y
# 1017     05/02/2020 10:14:23 PM                              Y
# 1528     01/14/2020 06:47:17 PM                              Y
# 630      05/10/2020 06:04:03 AM                              Y
# 9143     03/14/2020 09:49:34 PM                              Y
# 5729     01/06/2020 02:11:25 PM                              Y
# 5427     05/29/2020 11:39:40 PM                              Y
# 9        02/26/2020 03:16:35 PM                              Y
# 1099     01/30/2020 04:53:45 AM                              Y
#
#        DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  \
# 12468                            74    01/12/2020 09:40:23 PM  ...
# 1900                             15    03/08/2020 02:18:09 PM  ...
# 761                              93    02/15/2020 01:52:40 PM  ...
# 8050                             57    04/21/2020 03:38:49 AM  ...
# 9616                            937    01/27/2020 03:32:38 PM  ...
# 4279                             12    02/26/2020 01:06:59 PM  ...
# 8452                             11    04/23/2020 06:14:37 PM  ...
# 9264                              0                       NaN  ...
# 3019                             29    05/09/2020 02:37:01 AM  ...
# 10428                            32    01/23/2020 04:52:14 AM  ...
# 11961                            35    03/25/2020 07:25:36 AM  ...
# 11963                           148    03/20/2020 06:22:59 PM  ...
# 1017                             12    05/02/2020 10:14:40 PM  ...
# 1528                            117    01/14/2020 06:47:39 PM  ...
# 630                               8    05/10/2020 06:04:09 AM  ...
# 9143                             55    03/14/2020 09:49:45 PM  ...
# 5729                             16    01/06/2020 02:11:35 PM  ...
# 5427                              9    05/29/2020 11:39:52 PM  ...
# 9                                70    02/26/2020 03:16:49 PM  ...
# 1099                             11    01/30/2020 04:53:52 AM  ...
#
#       POLICEPRECINCT CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 12468           43.0                17.0              209.0
# 1900            84.0                33.0              302.0
# 761             49.0                13.0              211.0
# 8050           106.0                32.0              410.0
# 9616            17.0                 4.0              106.0
# 4279            94.0                33.0              301.0
# 8452            45.0                13.0              210.0
# 9264            42.0                17.0              203.0
# 3019            50.0                14.0              208.0
# 10428           40.0                17.0              201.0
# 11961          115.0                21.0              403.0
# 11963           68.0                43.0              310.0
# 1017            40.0                 8.0              201.0
# 1528            84.0                33.0              302.0
# 630            113.0                28.0              412.0
# 9143           105.0                27.0              413.0
# 5729           121.0                50.0              502.0
# 5427            44.0                14.0              204.0
# 9              106.0                28.0              410.0
# 1099            81.0                36.0              303.0
#
#        COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 12468                      8.0                  15.0                N
# 1900                      13.0                   7.0                N
# 761                       11.0                  14.0                N
# 8050                      27.0                   8.0                N
# 9616                       2.0                  12.0                N
# 4279                      14.0                  12.0                N
# 8452                       8.0                  14.0                N
# 9264                      12.0                  15.0                N
# 3019                      10.0                  13.0                N
# 10428                      7.0                  15.0                N
# 11961                     30.0                  14.0                N
# 11963                     20.0                  11.0                Y
# 1017                       7.0                  15.0                N
# 1528                      15.0                   7.0                N
# 630                       28.0                   5.0                N
# 9143                      29.0                   5.0                N
# 5729                      31.0                  11.0                N
# 5427                       9.0                  15.0                N
# 9                         27.0                   5.0                N
# 1099                      16.0                   8.0                N
#
#       SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  TRANSFER_INDICATOR  \
# 12468                       N                 N                   N
# 1900                        N                 N                   N
# 761                         N                 N                   N
# 8050                        N                 N                   N
# 9616                        N                 N                   N
# 4279                        N                 N                   N
# 8452                        N                 N                   N
# 9264                        N                 N                   N
# 3019                        N                 N                   N
# 10428                       N                 N                   N
# 11961                       N                 N                   N
# 11963                       N                 N                   N
# 1017                        N                 N                   N
# 1528                        N                 N                   N
# 630                         N                 N                   N
# 9143                        N                 N                   N
# 5729                        N                 N                   N
# 5427                        N                 N                   N
# 9                           N                 N                   N
# 1099                        N                 N                   N
#
#              source
# 12468  chunk165.csv
# 1900   chunk167.csv
# 761    chunk167.csv
# 8050   chunk170.csv
# 9616   chunk166.csv
# 4279   chunk167.csv
# 8452   chunk170.csv
# 9264   chunk168.csv
# 3019   chunk170.csv
# 10428  chunk166.csv
# 11961  chunk168.csv
# 11963  chunk168.csv
# 1017   chunk170.csv
# 1528   chunk165.csv
# 630    chunk170.csv
# 9143   chunk168.csv
# 5729   chunk165.csv
# 5427   chunk171.csv
# 9      chunk167.csv
# 1099   chunk166.csv
#
# [20 rows x 32 columns]

# %%
## how might you slice this df to show only rows 42 through 51 inclusive
ems2020_excerpt_df[42:52]
# Out:
#     CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 42        201542166  2020-06-02 14:39:16              CVAC
# 43        201290003  2020-05-08 00:02:09               EDP
# 44        201034249  2020-04-12 21:17:40              SICK
# 45        201784219  2020-06-26 22:59:45            INJURY
# 46        201001249  2020-04-09 08:29:26            INJURY
# 47        200880324  2020-03-28 01:22:22              SICK
# 48        201323660  2020-05-11 23:40:32               UNC
# 49        201632450  2020-06-11 16:18:15            TRAUMA
# 50        200630307  2020-03-03 02:35:05              SICK
# 51        200314692  2020-01-31 22:35:56            STATEP
#
#     INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 42                            2            CVAC                          2
# 43                            7             EDP                          7
# 44                            6            SICK                          6
# 45                            5          INJURY                          5
# 46                            5          INJURY                          5
# 47                            6            SICK                          6
# 48                            2             UNC                          2
# 49                            2          TRAUMA                          2
# 50                            6            SICK                          6
# 51                            2          STATEP                          2
#
#    FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 42    06/02/2020 02:39:24 PM                              Y
# 43    05/08/2020 12:02:34 AM                              Y
# 44    04/12/2020 09:20:33 PM                              Y
# 45    06/26/2020 10:59:54 PM                              Y
# 46    04/09/2020 08:29:30 AM                              Y
# 47    03/28/2020 01:23:56 AM                              Y
# 48    05/11/2020 11:40:43 PM                              Y
# 49    06/11/2020 04:18:34 PM                              Y
# 50    03/03/2020 02:35:16 AM                              Y
# 51    01/31/2020 10:36:21 PM                              Y
#
#     DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  \
# 42                             8    06/02/2020 02:39:43 PM  ...
# 43                            25    05/08/2020 12:02:55 AM  ...
# 44                           173    04/12/2020 09:20:33 PM  ...
# 45                             9    06/26/2020 11:00:01 PM  ...
# 46                             4    04/09/2020 08:29:55 AM  ...
# 47                            94    03/28/2020 01:24:07 AM  ...
# 48                            11    05/11/2020 11:40:48 PM  ...
# 49                            19    06/11/2020 04:19:07 PM  ...
# 50                            11    03/03/2020 02:35:46 AM  ...
# 51                            25    01/31/2020 10:36:32 PM  ...
#
#    POLICEPRECINCT CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 42           88.0                35.0              302.0
# 43           23.0                 8.0              111.0
# 44           75.0                37.0              305.0
# 45          114.0                22.0              401.0
# 46          122.0                50.0              502.0
# 47            5.0                 1.0              101.0
# 48           40.0                 8.0              201.0
# 49           67.0                40.0              317.0
# 50           79.0                36.0              303.0
# 51          114.0                26.0              401.0
#
#     COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 42                     13.0                   8.0                N
# 43                      4.0                  13.0                N
# 44                     19.0                   8.0                N
# 45                     30.0                  12.0                N
# 46                     31.0                  11.0                N
# 47                      2.0                   7.0                N
# 48                      7.0                  15.0                Y
# 49                     17.0                   9.0                N
# 50                     16.0                   8.0                N
# 51                     30.0                  12.0                N
#
#    SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 42                       N                 N                   N  chunk171.csv
# 43                       N                 N                   N  chunk170.csv
# 44                       N                 N                   N  chunk169.csv
# 45                       N                 N                   N  chunk172.csv
# 46                       N                 N                   N  chunk169.csv
# 47                       N                 N                   N  chunk168.csv
# 48                       N                 N                   N  chunk170.csv
# 49                       N                 N                   N  chunk171.csv
# 50                       N                 N                   N  chunk167.csv
# 51                       N                 N                   N  chunk166.csv
#
# [10 rows x 32 columns]

# %%
## store rows 42 through 51 inclusive into a df called df_excerpt
df_excerpt = ems2020_excerpt_df[42:52]

# %%
## get basic overview of the data
## what datatypes do the different columns hold?
## how many rows and columns are there

df_excerpt.info()
## the cols hold integers, objects (typically strings or dates), and floats (i.e. values with decimals)
## there are 32 columns and 10 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 42 to 51
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CAD_INCIDENT_ID                 10 non-null     int64
#  1   INCIDENT_DATETIME               10 non-null     object
#  2   INITIAL_CALL_TYPE               10 non-null     object
#  3   INITIAL_SEVERITY_LEVEL_CODE     10 non-null     int64
#  4   FINAL_CALL_TYPE                 10 non-null     object
#  5   FINAL_SEVERITY_LEVEL_CODE       10 non-null     int64
#  6   FIRST_ASSIGNMENT_DATETIME       10 non-null     object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  10 non-null     object
#  8   DISPATCH_RESPONSE_SECONDS_QY    10 non-null     int64
#  9   FIRST_ACTIVATION_DATETIME       10 non-null     object
#  10  FIRST_ON_SCENE_DATETIME         10 non-null     object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  10 non-null     object
#  12  INCIDENT_RESPONSE_SECONDS_QY    10 non-null     float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   10 non-null     float64
#  14  FIRST_TO_HOSP_DATETIME          4 non-null      object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     4 non-null      object
#  16  INCIDENT_CLOSE_DATETIME         10 non-null     object
#  17  HELD_INDICATOR                  10 non-null     object
#  18  INCIDENT_DISPOSITION_CODE       10 non-null     float64
#  19  BOROUGH                         10 non-null     object
#  20  INCIDENT_DISPATCH_AREA          10 non-null     object
#  21  ZIPCODE                         10 non-null     float64
#  22  POLICEPRECINCT                  10 non-null     float64
#  23  CITYCOUNCILDISTRICT             10 non-null     float64
#  24  COMMUNITYDISTRICT               10 non-null     float64
#  25  COMMUNITYSCHOOLDISTRICT         10 non-null     float64
#  26  CONGRESSIONALDISTRICT           10 non-null     float64
#  27  REOPEN_INDICATOR                10 non-null     object
#  28  SPECIAL_EVENT_INDICATOR         10 non-null     object
#  29  STANDBY_INDICATOR               10 non-null     object
#  30  TRANSFER_INDICATOR              10 non-null     object
#  31  source                          10 non-null     object
# dtypes: float64(9), int64(4), object(19)
# memory usage: 2.6+ KB

# %% [markdown]
# ## Targeting an Excel sheet
#
# We need the Customs and Border Protection data in this ```multi-data.xlsx``` workbook.

# %%
## import data here
df_cps = pd.read_excel("raw_data/multi-data.xlsx", sheet_name = "CBP")

# %%
## call the top 15 rows
df_cps15 = pd.read_excel("raw_data/multi-data.xlsx", sheet_name = "CBP", skiprows = 6)
df_cps15.head(15)
# Out:
#                date_in            date_out  hours_in_custody     age_group  \
# 0  2017-01-20 00:10:00 2017-01-20 10:08:00          9.950000     6-8 years
# 1  2017-01-20 00:15:00 2017-01-24 17:30:00        113.233333     3-5 years
# 2  2017-01-20 00:22:00 2017-01-24 17:47:00        113.416667     3-5 years
# 3  2017-01-20 00:30:00 2017-01-21 06:35:00         30.083333   12-14 years
# 4  2017-01-20 00:30:00 2017-01-21 13:03:00         36.533333     3-5 years
# 5  2017-01-20 00:30:00 2017-01-21 15:30:00         38.983333  Under 1 year
# 6  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667     6-8 years
# 7  2017-01-20 00:35:00 2017-01-20 15:14:00         14.633333     6-8 years
# 8  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667     3-5 years
# 9  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667    9-11 years
# 10 2017-01-20 00:45:00 2017-01-20 13:15:00         12.500000   15-18 years
# 11 2017-01-20 01:19:00 2017-01-21 02:30:00         25.166667   15-18 years
# 12 2017-01-20 01:19:00 2017-01-21 02:30:00         25.166667   15-18 years
# 13 2017-01-20 01:20:00 2017-01-24 17:30:00        112.166667     6-8 years
# 14 2017-01-20 01:20:00 2017-01-20 13:40:00         12.333333    9-11 years
#
#     gender  citizenship border      sector  field_office
# 0   Female  EL SALVADOR    SBO  (b)(7)(E )           NaN
# 1   Female    GUATEMALA    SBO  (b)(7)(E )           NaN
# 2   Female       BRAZIL    SBO  (b)(7)(E )           NaN
# 3     Male  EL SALVADOR    SBO  (b)(7)(E )           NaN
# 4     Male     HONDURAS    SBO  (b)(7)(E )           NaN
# 5     Male     HONDURAS    SBO  (b)(7)(E )           NaN
# 6     Male    GUATEMALA    SBO  (b)(7)(E )           NaN
# 7     Male    GUATEMALA    SBO  (b)(7)(E )           NaN
# 8     Male    GUATEMALA    SBO  (b)(7)(E )           NaN
# 9     Male    GUATEMALA    SBO  (b)(7)(E )           NaN
# 10    Male  EL SALVADOR    SBO  (b)(7)(E )           NaN
# 11    Male        INDIA    SBO  (b)(7)(E )           NaN
# 12    Male        INDIA    SBO  (b)(7)(E )           NaN
# 13    Male     HONDURAS    SBO  (b)(7)(E )           NaN
# 14  Female  EL SALVADOR    SBO  (b)(7)(E )           NaN
